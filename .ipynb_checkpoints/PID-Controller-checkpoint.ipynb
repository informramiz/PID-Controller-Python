# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# ------------------------------------------------
# 
# this is the Robot class
#
class Robot(object):
    def __init__(self, length=20.0):
        """
        Creates robot and initializes location/orientation to 0, 0, 0.
        """
        self.x = 0.0
        self.y = 0.0
        self.orientation = 0.0
        self.length = length
        self.steering_noise = 0.0
        self.distance_noise = 0.0
        self.steering_drift = 0.0

    def set(self, x, y, orientation):
        """
        Sets a robot coordinate.
        """
        self.x = x
        self.y = y
        self.orientation = orientation % (2.0 * np.pi)

    def set_noise(self, steering_noise, distance_noise):
        """
        Sets the noise parameters.
        """
        # makes it possible to change the noise parameters
        # this is often useful in particle filters
        self.steering_noise = steering_noise
        self.distance_noise = distance_noise

    def set_steering_drift(self, drift):
        """
        Sets the systematical steering drift parameter
        """
        self.steering_drift = drift

    def move(self, steering, distance, tolerance=0.001, max_steering_angle=np.pi / 4.0):
        """
        steering = front wheel steering angle, limited by max_steering_angle
        distance = total distance driven, most be non-negative
        """
        if steering > max_steering_angle:
            steering = max_steering_angle
        if steering < -max_steering_angle:
            steering = -max_steering_angle
        if distance < 0.0:
            distance = 0.0

        # apply noise
        steering2 = random.gauss(steering, self.steering_noise)
        distance2 = random.gauss(distance, self.distance_noise)

        # apply steering drift
        steering2 += self.steering_drift

        # Execute motion
        turn = np.tan(steering2) * distance2 / self.length

        if abs(turn) < tolerance:
            # approximate by straight line motion
            self.x += distance2 * np.cos(self.orientation)
            self.y += distance2 * np.sin(self.orientation)
            self.orientation = (self.orientation + turn) % (2.0 * np.pi)
        else:
            # approximate bicycle model for motion
            radius = distance2 / turn
            cx = self.x - (np.sin(self.orientation) * radius)
            cy = self.y + (np.cos(self.orientation) * radius)
            self.orientation = (self.orientation + turn) % (2.0 * np.pi)
            self.x = cx + (np.sin(self.orientation) * radius)
            self.y = cy - (np.cos(self.orientation) * radius)

    def __repr__(self):
        return '[x=%.5f y=%.5f orient=%.5f]' % (self.x, self.y, self.orientation)

# %% [markdown]
# ## P-Controller (Proportional Controller)

# %%
# Implement a P controller by running 100 iterations
# of robot motion. The desired trajectory for the 
# robot is the x-axis. The steering angle should be set
# by the parameter tau so that:
#
# steering = -tau * crosstrack_error
# where crosstrack_error = y-axis value and reference trajectory is x-axis

# %%
# ------------------------------------------------------------------------
#
# run - does a single control run
robot = Robot()
robot.set(0, 1, 0)

def run_p(robot, tau, n=100, speed=1.0):
    x_trajectory = []
    y_trajectory = []
    for i in range(n):
        #as in this example Cross Track Error (CTE) = robot.y so
        steering = -tau * robot.y
        robot.move(steering, speed)
        x_trajectory.append(robot.x)
        y_trajectory.append(robot.y)
        
    return x_trajectory, y_trajectory
    
x_trajectory, y_trajectory = run_p(robot, 0.3)
n = len(x_trajectory)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 8))
ax1.plot(x_trajectory, y_trajectory, 'g', label='P controller')
ax1.plot(x_trajectory, np.zeros(n), 'r', label='reference')

# %% [markdown]
# ## PD-Controller (Proportional Derivative-Controller)

# %%
#
# Implement a PD controller by running 100 iterations
# of robot motion. The steering angle should be set
# by the parameter tau_p and tau_d so that:
#
# steering = -tau_p * CTE - tau_d * diff_CTE
# where differential crosstrack error (diff_CTE)
# is given by CTE(t) - CTE(t-1)
#
#

# %%
def run_PD(robot, tau_p, tau_d, n=100, speed=1.0):
    x_trajectory = []
    y_trajectory = []
    
    prev_cte = robot.y
    for i in range(n):
        cte = robot.y
        cte_change = cte - prev_cte
        prev_cte = cte
        
        steering = -tau_p*cte - tau_d*cte_change
        robot.move(steering, speed)
        
        x_trajectory.append(robot.x)
        y_trajectory.append(robot.y)
        
    return x_trajectory, y_trajectory
    
# run - does a single control run
robot = Robot()
robot.set(0, 1, 0)
x_trajectory, y_trajectory = run_PD(robot, 0.2, 3.0)
n = len(x_trajectory)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 8))
ax1.plot(x_trajectory, y_trajectory, 'g', label='PD controller')
ax1.plot(x_trajectory, np.zeros(n), 'r', label='reference')

# %% [markdown]
# ## PID-Controller (Proportional Integral Derivative-Controller)

# %% [markdown]
# Let's set some steering drift (system bias, steering is not working perfect or wheels are not perfectly aligned) and see what happens.

# %%
# try on P-Controller
robot = Robot()
robot.set(0, 1, 0)
#add a bias
robot.set_steering_drift(10.0 / 180.0 * np.pi) #10 degrees of drift
x_trajectory, y_trajectory = run_PD(robot, 0.2, 0)
n = len(x_trajectory)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 8))
ax1.plot(x_trajectory, y_trajectory, 'g', label='P controller')
ax1.plot(x_trajectory, np.zeros(n), 'r', label='reference')

# %%
# try on PD-Controller
robot = Robot()
robot.set(0, 1, 0)
#add a bias
robot.set_steering_drift(10.0 / 180.0 * np.pi)
x_trajectory, y_trajectory = run_PD(robot, 0.2, 3.0)
n = len(x_trajectory)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 8))
ax1.plot(x_trajectory, y_trajectory, 'g', label='P controller')
ax1.plot(x_trajectory, np.zeros(n), 'r', label='reference')

# %% [markdown]
# Now try it with PID-Controller

# %%
def run_PID(robot, tau_p, tau_d, tau_i, n=200, speed=1.0):
    x_trajectory = []
    y_trajectory = []
    
    prev_cte = robot.y
    error_sum = 0
    for i in range(n):
        cte = robot.y
        cte_change = cte - prev_cte
        prev_cte = cte
        
        error_sum += cte
        steering = -tau_p*cte - tau_d*cte_change - tau_i*error_sum
        robot.move(steering, speed)
        
        x_trajectory.append(robot.x)
        y_trajectory.append(robot.y)
        
    return x_trajectory, y_trajectory
    
# run - does a single control run
robot = Robot()
robot.set(0, 1, 0)
#add a bias
robot.set_steering_drift(10.0 / 180.0 * np.pi)
x_trajectory, y_trajectory = run_PID(robot, 0.2, 3.0, 0.005)
n = len(x_trajectory)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 8))
ax1.plot(x_trajectory, y_trajectory, 'g', label='PD controller')
ax1.plot(x_trajectory, np.zeros(n), 'r', label='reference')

# %% [markdown]
# ## Twiddle/Coordinate Descent (Parameters optimization)

# %%
def make_robot():
    """
    Resets the robot back to the initial position and drift.
    You'll want to call this after you call `run`.
    """
    robot = Robot()
    robot.set(0, 1, 0)
    robot.set_steering_drift(10 / 180 * np.pi)
    return robot

# NOTE: We use params instead of tau_p, tau_d, tau_i
def run_PID_optimized(robot, params, n=100, speed=1.0):
    x_trajectory = []
    y_trajectory = []
    err = 0
    # TODO: your code here
    prev_cte = robot.y
    cte_sum = 0
    #let's run 2n times to given algorithm enough time to converge 
    for i in range(2 * n):
        cte = robot.y
        diff_cte = cte - prev_cte
        cte_sum += cte
        prev_cte = cte
        
        steer = -params[0] * cte - params[1] * diff_cte - params[2] * cte_sum
        robot.move(steer, speed)
        
        x_trajectory.append(robot.x)
        y_trajectory.append(robot.y)
        #try calculating error to return, after n iterations 
        #so that algorithm is converged enough before
        if i >= n:
            err += cte ** 2
            
    return x_trajectory, y_trajectory, err / n


# Make this tolerance bigger if you are timing out!
def twiddle(tol=0.2): 
    # Don't forget to call `make_robot` before you call `run`!
    p = [0, 0, 0]
    dp = [1, 1, 1]
    robot = make_robot()
    
    #run PID controller on intial P
    x_trajectory, y_trajectory, best_err = run_PID_optimized(robot, p)
    
    # TODO: twiddle loop here
    
    #do until sum(dp) is greater than some threshold
    while sum(dp) > tol:
        
        for i in range(len(p)):
            #try increasing p[i] by value dp[i] to see if it decreases error
            p[i] += dp[i]
            #try PID controller on updated values of p
            robot = make_robot()
            x, y, err = run_PID_optimized(robot, p)
            
            #check if err is decreased than before's best_err
            if err < best_err:
                #increasing by value dp[i] improved error than before's best_err so
                #update best error to new improved error 
                best_err = err 
                #increase dp[i] value for next iteration
                dp[i] *= 1.1
                continue;
            else: #increasing p[i] by dp[i] did not help
                #reset p[i] back to value that was at the start of this iteration
                #which is: revert this above step --> p[i] += dp[i]
                p[i] -= dp[i]
                
            #increasing did not help so let's try decreasing p[i] by value dp[i]
            p[i] -= dp[i]
            #try PID controller on updated values of p
            robot = make_robot()
            x, y, err = run_PID_optimized(robot, p)
            
            #check if err is decreased than before's best_err
            if err < best_err:
                #decreasing by value dp[i] improved error than before's best_err so
                #update best error to new improved error 
                best_err = err 
                #increase dp[i] value for next iteration to increase jump/interval value
                dp[i] *= 1.1
                continue;
            else: #decreasing p[i] by dp[i] did not help
                #reset p[i] back to value that was at the start of this iteration
                #which is: revert this above step --> p[i] -= dp[i]
                p[i] += dp[i]
                
                #as both increasing and decreasing did not help so
                #we should decrease dp[i] value/interval to try on 
                #smaller increments/decrements to p[i]
                dp[i] *= 0.9
            
    
    return p, best_err


params, err_final = twiddle()
print("Final twiddle error = {}".format(err_final))
robot = make_robot()
x_trajectory, y_trajectory, err_final = run_PID_optimized(robot, params)
n = len(x_trajectory)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 8))
ax1.plot(x_trajectory, y_trajectory, 'g', label='Twiddle PID controller')
ax1.plot(x_trajectory, np.zeros(n), 'r', label='reference')
# Out:
# Final twiddle error = 3.611462462689709e-17
